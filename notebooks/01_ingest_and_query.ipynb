# %% [markdown]
# # Document Q&A with LangChain + FAISS\nNotebook-first workflow using the same service code as CLI/API.

# %%
from pathlib import Path\nfrom src.service import DocumentQAService

# %%
service = DocumentQAService()\nraw_dir = Path('data/raw')\nraw_dir.mkdir(parents=True, exist_ok=True)

# %%
# Add your docs to data/raw before running this\ningest_result = service.ingest(paths=[str(raw_dir)], corpus_id='default')\ningest_result

# %%
response = service.ask('What is this corpus about?', corpus_id='default', top_k=4)\nresponse
